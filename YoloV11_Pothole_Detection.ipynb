# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YoloV11_Potholes_Detection
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection

# %%
# !pip -q install roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.0 MB/s eta 0:00:00

# %%
# !mkdir {HOME}/datasets

# %%
# %cd {HOME}/datasets

from roboflow import Roboflow
rf = Roboflow(api_key="wZjRSm2COEhivHpubFLO")
project = rf.workspace("potholesdetection-aq76f").project("detection-potholes-classes")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Detection-Potholes-Classes-7 in yolov8:: 100%|██████████| 3144/3144 [00:27<00:00, 112.65it/s]

# %%
# %pip -q install ultralytics  # install
from ultralytics import YOLO, checks, hub

checks()  # checks
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 36.6/112.6 GB disk)

# %%
# %cd {HOME}

# !yolo task=segment mode=train model=yolo11m-seg.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 box=5 cls=0.3 dfl=5 batch=16 weight_decay=0.00001
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection
# ...
# 100% 43.3M/43.3M [00:00<00:00, 84.8MB/s]
# Ultralytics 8.3.5 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_path = "/content/drive/MyDrive/YoloV11_Potholes_Detection/runs/segment/train/weights/best.pt"

# %%
data_yaml_path = "/content/drive/MyDrive/YoloV11_Potholes_Detection/datasets/Detection-Potholes-Classes-7/data.yaml"

# %%
# %cd {HOME}
# !yolo task=segment mode=val model={model_path} conf=0.7 iou=0.7 data={data_yaml_path}
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection
# Ultralytics 8.3.5 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m-seg summary (fused): 330 layers, 22,337,625 parameters, 0 gradients, 123.0 GFLOPs
# val: Scanning /content/drive/MyDrive/YoloV11_Potholes_Detection/datasets/Detection-Potholes-Classes-7/valid/labels.cache... 312 images, 2 backgrounds, 0 corrupt: 100% 312/312 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:13<00:00,  1.50it/s]
#                    all        312        923      0.738      0.256      0.494      0.346      0.732      0.255      0.489      0.318
#         medium-pothole        179        337      0.646       0.19      0.411      0.301      0.646       0.19       0.41       0.29
#           risk-pothole        159        249      0.816      0.446       0.63      0.479      0.816      0.446       0.63       0.46
# ...

# %%
# %cd {HOME}
# !yolo task=segment mode=val model={model_path} conf=0.25 iou=0.7 data={data_yaml_path}
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection
# Ultralytics 8.3.6 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m-seg summary (fused): 330 layers, 22,337,625 parameters, 0 gradients, 123.0 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 22.6MB/s]
# val: Scanning /content/drive/MyDrive/YoloV11_Potholes_Detection/datasets/Detection-Potholes-Classes-7/valid/labels.cache... 312 images, 2 backgrounds, 0 corrupt: 100% 312/312 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:21<00:00,  1.06s/it]
#                    all        312        923      0.495      0.459      0.468      0.304      0.486      0.443      0.457      0.277
#         medium-pothole        179        337       0.42      0.433      0.396      0.257      0.421      0.421      0.392      0.236
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="wZjRSm2COEhivHpubFLO")
project = rf.workspace("potholesdetection-aq76f").project("detection-potholes-classes")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.3.5, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Detection-Potholes-Classes-6 in yolov8:: 100%|██████████| 7536/7536 [01:12<00:00, 104.58it/s]

# %%
data_yaml_path_2 = '/content/drive/MyDrive/YoloV11_Potholes_Detection/Detection-Potholes-Classes-6/data.yaml'

# %%
# !yolo task=segment mode=train model={model_path} \
data={data_yaml_path_2} \
epochs=100 imgsz=640 box=5 cls=0.25 iou=0.6 optimizer=AdamW lr0=0.0001 batch=16 weight_decay=0.001
# Out:
# Ultralytics 8.3.6 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
data_yaml_2 = '/content/drive/MyDrive/YoloV11_Potholes_Detection/Detection-Potholes-Classes-6/data.yaml'

# %%
model_path_2 = '/content/drive/MyDrive/YoloV11_Potholes_Detection/runs/segment/train3/weights/best.pt'

# %%
# %cd {HOME}
# !yolo task=segment mode=val model={model_path_2} conf=0.25 iou=0.7 data={data_yaml_2}
# Out:
# /content/drive/MyDrive/YoloV11_Potholes_Detection
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m-seg summary (fused): 330 layers, 22,337,625 parameters, 0 gradients, 123.0 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 22.1MB/s]
# val: Scanning /content/drive/MyDrive/YoloV11_Potholes_Detection/Detection-Potholes-Classes-6/valid/labels.cache... 312 images, 2 backgrounds, 0 corrupt: 100% 312/312 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:22<00:00,  1.13s/it]
#                    all        312        923      0.444      0.431      0.423      0.278      0.423      0.411      0.407      0.241
#         medium-pothole        179        337      0.405      0.398      0.357      0.224      0.384      0.377      0.342        0.2
# ...
